# %% [markdown]
# <a href="https://colab.research.google.com/github/sneharreddy25/project_2025/blob/main/TEXT_TO_PDF_WITH_NER__.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# TEXT TO PDF WITH NER Proj_--

# %%
# !pip install PyMuPDF
# !pip install spacy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 51.3 MB/s eta 0:00:00
# ...

# %%
import fitz  # PyMuPDF
import spacy

# Define the function with a proper parameter name, e.g., 'pdf_path'
def extract_text_from_pdf(pdf_path):
    # Use the parameter 'pdf_path' to open the file
    doc = fitz.open(pdf_path)
    text = ""
    for page in doc:
        text += page.get_text()
    return text

# Load the English NER model
nlp = spacy.load("en_core_web_sm")

def apply_ner(text, chunk_size=500000): # Added chunk_size parameter
    # Split the text into chunks
    text_chunks = [text[i:i + chunk_size] for i in range(0, len(text), chunk_size)]

    print("Processing text in chunks...")
    for i, chunk in enumerate(text_chunks):
        print(f"Processing chunk {i+1}/{len(text_chunks)}")
        doc = nlp(chunk)
        # Process named entities for the current chunk
        for ent in doc.ents:
            print(f"{ent.text} ({ent.label_}): {spacy.explain(ent.label_)}")

fghfgh = extract_text_from_pdf("/content/IES-Examination-pattern-and-syllabus.pdf")
apply_ner(fghfgh) # Call the function with the extracted text
# Out:
# Processing text in chunks...
# Processing chunk 1/1
# Indian Engineering Services (ORG): Companies, agencies, institutions, etc.
# The Indian Engineering Services (ORG): Companies, agencies, institutions, etc.
# India (GPE): Countries, cities, states
# Indian Engineering Services (ORG): Companies, agencies, institutions, etc.
# Engineering Services Examination (ORG): Companies, agencies, institutions, etc.
# ESE (ORG): Companies, agencies, institutions, etc.
# Union Public Services Commission (ORG): Companies, agencies, institutions, etc.
# three (CARDINAL): Numerals that do not fall under another type
# the Engineering Services Examination (ORG): Companies, agencies, institutions, etc.
# ESE (ORG): Companies, agencies, institutions, etc.
# the Indian Engineering Services (ORG): Companies, agencies, institutions, etc.
# the Government of India (ORG): Companies, agencies, institutions, etc.
# The Engineering Services Examination (ORG): Companies, agencies, institutions, etc.
# ...
